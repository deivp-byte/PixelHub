# %%
import sys
sys.path.append("../src")

# %%
# Prove d'insercio a traves de un pattern (CRUD)

# %%
session= Session(bind=engine)
userRepository = UserRepository(session)
print(userRepository.get_all())
session.commit()
# Out:
# [id:4 username:user1 email:user1@example.com created at: 2026-04-20, id:5 username:user2 email:user2@example.com created at: 2026-04-20, id:6 username:user3 email:user3@example.com created at: 2026-04-20, id:7 username:user4 email:user4@example.com created at: 2026-04-20, id:8 username:user5 email:user5@example.com created at: 2026-04-20, id:13 username:UserProves email:UserProves1@gmail.com created at: 2026-04-20]

# %%
session= Session(bind=engine)
userRepository = UserRepository(session)
userRepository.delete(1)
session.commit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 session= Session(bind=engine)
#       2 userRepository = UserRepository(session)
# ----> 3 userRepository.delete(1)
#       4 session.commit()
#
# File c:\Archivos\DAM\acces_dades\PixelHub\PixelHub\notebooks\../src\domain\repository.py:37, in Repository.delete(self, k)
#      34 v= self.get(k)
#      35 # if v is None:
#      36 #     raise ValueError(f"User does not exist")
# ---> 37 self._validate(v)
#      38 self.session.delete(v)
#
# File c:\Archivos\DAM\acces_dades\PixelHub\PixelHub\notebooks\../src\domain\repository.py:44, in UserRepository._validate(self, user)
#      43 def _validate(self, user:User)-> None:
# ---> 44     if user.username is None:
#      45         raise ValueError("User name is mandatory")
#      46     elif user.id is None:
#
# AttributeError: 'NoneType' object has no attribute 'username'

# %%
session= Session(bind=engine)

UserProve=User()
UserProve.username= "UserProves"
UserProve.email = "UserProves2@gmail.com"
UserProve.password = "UserProves_Password2"
UserProve.role_id=1
userRepository = UserRepository(session)
userRepository.save(UserProve)

session.commit()

# %%
print(UserProve.id)
# Out:
# None
